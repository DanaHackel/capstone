# %%
import pandas as pd
import requests
import csv

# %%
base_url = 'https://api.fda.gov/drug/drugsfda.json?count='
brand_name = requests.get(base_url+'openfda.brand_name.exact')

# %%
brand_name.status_code
# Out:
# 200

# %%
drug_brand_names = brand_name.json()

# %%
drug_brand_names.keys()
# Out:
# dict_keys(['meta', 'results'])

# %%
pd.DataFrame(drug_brand_names['results'])

#trying to pull just the terms, but it wont work? what am i doing wrong?
# Out:
#                              term  count
# 0           CLOBETASOL PROPIONATE     69
# 1                   LEVETIRACETAM     49
# 2         METFORMIN HYDROCHLORIDE     47
# 3                       IBUPROFEN     46
# 4   METHYLPHENIDATE HYDROCHLORIDE     42
# ..                            ...    ...
# 95                            AIR     17
# 96           ATORVASTATIN CALCIUM     17
# 97                     CEPHALEXIN     17
# 98                    DEFERASIROX     17
# 99              DIVALPROEX SODIUM     17
#
# [100 rows x 2 columns]

# %%
#openfda.generic_name.exact
products = pd.read_csv('Products.txt', sep='\t')
products.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-93-6c9a7d587d1e> in <module>
#       1 #openfda.generic_name.exact
# ----> 2 products = pd.read_csv('Products.txt', sep='\t')
#       3 products.head()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
drug_list = []
with open('Products.txt', newline = '') as products:                                                                                          
    drug_reader = csv.DictReader(products, delimiter='\t')
    for drug in drug_reader:
        drug_list.append(dict(drug))
drug_df = pd.DataFrame(drug_list)
drug_df

#https://www.pluralsight.com/guides/importing-data-from-tab-delimited-files-with-python via Noah
# Out:
#        ApplNo ProductNo                       Form                 Strength  \
# 0      000004       004  SOLUTION/DROPS;OPHTHALMIC                       1%
# 1      000159       001                TABLET;ORAL                    500MG
# 2      000552       001       INJECTABLE;INJECTION          20,000 UNITS/ML
# 3      000552       002       INJECTABLE;INJECTION          40,000 UNITS/ML
# 4      000552       003       INJECTABLE;INJECTION           5,000 UNITS/ML
# ...       ...       ...                        ...                      ...
# 41208  761154       001       INJECTABLE;INJECTION               20MG;0.4ML
# 41209  761156       001       INJECTABLE;INJECTION               10MG/1.5ML
# 41210  761158       001     INJECTABLE;INTRAVENOUS                 2.5MG/KG
# 41211  761163       001       INJECTABLE;INJECTION                  12MG/KG
# 41212  761170       001    INJECTABLE;SUBCUTANEOUS  1200MG;600MG;30000UNITS
#
# ...
