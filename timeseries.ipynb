# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#planning to revisit this thursday with all_drugs csv as the frequencies have changed slightly 
nadac = pd.read_csv('./data/nadac.csv')

# %%
#the top 20 mentions are all generics - as seen in the eda_nadac notebook
top_drugs = nadac['NDC Description'].value_counts().sort_values(ascending = False)
unique_drugs = top_drugs.index.unique()
top_20_drugs = unique_drugs[:20].tolist()
top_20_drugs
top_20_drugs_df = nadac[(nadac['NDC Description'] == 'METFORMIN HCL 500MG TABLET')|
                       (nadac['NDC Description'] =='METFORMIN HCL 1,000MG TABLET')|
                       (nadac['NDC Description'] =='MONTELUKAST SOD 10MG TABLET')|
                       (nadac['NDC Description'] =='METFORMIN HCL 850MG TABLET')|
                       (nadac['NDC Description'] =='AMLODIPINE BESYLATE 5MG TABLET')|
                        (nadac['NDC Description'] == 'LISINOPRIL 20MG TABLET')|
                        (nadac['NDC Description'] == 'LOSARTAN POTASSIUM 50MG TABLET')|
                        (nadac['NDC Description'] == 'LOSARTAN POTASSIUM 100MG TABLET')|
                        (nadac['NDC Description'] == 'LISINOPRIL 10MG TABLET')|
                        (nadac['NDC Description'] == 'LISINOPRIL 40MG TABLET')|
                        (nadac['NDC Description'] == 'GABAPENTIN 300MG CAPSULE')|
                        (nadac['NDC Description'] == 'IBUPROFEN 200MG TABLET')|
                        (nadac['NDC Description'] == 'LISINOPRIL 5MG TABLET')|
                        (nadac['NDC Description'] == 'DONEPEZIL HCL 5MG TABLET')|
                        (nadac['NDC Description'] == 'FINASTERIDE 5MG TABLET')| 
                        (nadac['NDC Description'] == 'CLOPIDOGREL 75MG TABLET')|
                        (nadac['NDC Description'] == 'AMLODIPINE BESYLATE 2.5MG TABLET')|
                        (nadac['NDC Description'] == 'OMEPRAZOLE DR 20MG CAPSULE')|
                        (nadac['NDC Description'] == 'GABAPENTIN 100MG CAPSULE')]
                        
# #top_5_drugs_df.head()

# %%
top_20_drugs_df.shape
# Out:
# (341364, 13)

# %%
top_20_drugs_df['Effective_Date'] = pd.to_datetime(top_20_drugs_df['Effective_Date'])
top_20_drugs_df['Effective_Date']
# Out:
# C:\Users\12155\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 5         2016-02-17
# 25        2016-02-17
# 57        2016-03-23
# 64        2016-03-23
# 79        2016-03-23
#              ...
# 8590610   2020-08-19
# 8590615   2020-08-19
# 8590665   2020-08-19
# 8590711   2020-08-19
# 8590727   2020-08-19
# Name: Effective_Date, Length: 341364, dtype: datetime64[ns]

# %%
brands = nadac[nadac['Classification_for_Rate_Setting']=='B']
top_brands = brands['NDC Description'].value_counts().sort_values(ascending = False)
top_20_brands = top_brands[:20].index.unique()
top_20_brands
top_20_brands_df = nadac[(nadac['NDC Description'] == 'NICORETTE 2MG CHEWING GUM')|
                        (nadac['NDC Description'] == 'NICORETTE 4MG CHEWING GUM')|
                        (nadac['NDC Description'] == 'TUMS E-X TABLET CHEWABLE')|
                        (nadac['NDC Description'] == 'TUMS ULTRA TABLET CHEWABLE')|
                        (nadac['NDC Description'] == 'MUCINEX ER 600MG TABLET')|
                        (nadac['NDC Description'] == 'DELSYM 30MG/5ML SUSPENSION')|
                        (nadac['NDC Description'] == 'EXCEDRIN EXTRA STRENGTH CAPLET')|
                        (nadac['NDC Description'] == 'JANUVIA 100MG TABLET')|
                        (nadac['NDC Description'] == 'NEXIUM DR 40MG CAPSULE')|
                        (nadac['NDC Description'] == 'TUMS TABLET CHEWABLE')|
                        (nadac['NDC Description'] == 'CEPACOL SORE THROAT LOZENGE')|
                        (nadac['NDC Description'] == 'ZANTAC 150MG TABLET')|
                        (nadac['NDC Description'] == 'KLOR-CON 10 MEQ TABLET')|
                        (nadac['NDC Description'] == 'NICORETTE 2MG LOZENGE')|
                        (nadac['NDC Description'] == 'ZETIA 10MG TABLET')|
                        (nadac['NDC Description'] == 'NICODERM CQ 21MG/24HR PATCH')|
                        (nadac['NDC Description'] == 'GAS-X EXTRA STRENGTH SOFTGEL')|
                        (nadac['NDC Description'] == 'KLOR-CON 8 MEQ TABLET')|
                        (nadac['NDC Description'] == 'NICORETTE 4MG LOZENGE')|
                        (nadac['NDC Description'] == 'EFFEXOR XR 150MG CAPSULE')]


top_20_brands_df.head()
# Out:
#       Unnamed: 0              NDC Description          NDC  NADAC_Per_Unit  \
# 51            51            ZETIA 10MG TABLET  66582041454         8.35885
# 274          274            ZETIA 10MG TABLET  66582041474         7.60583
# 411          411            ZETIA 10MG TABLET  66582041454         7.60583
# 1058        1058         JANUVIA 100MG TABLET      6027754        10.81613
# 1532        1532  CEPACOL SORE THROAT LOZENGE  63824073016         0.16016
#
#      Effective_Date Pricing_Unit Pharmacy_Type_Indicator OTC Explanation_Code  \
# 51       01/07/2016           EA                     C/I   N                2
# 274      06/04/2015           EA                     C/I   N                2
# 411      06/04/2015           EA                     C/I   N                2
# 1058     01/06/2015           EA                     C/I   N                2
# 1532     07/01/2015           EA                     C/I   Y             3, 6
#
#      Classification_for_Rate_Setting  \
# ...

# %%
top_20_brands_df['Effective_Date'] = pd.to_datetime(top_20_brands_df['Effective_Date'])
# Out:
# C:\Users\12155\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
top_20_brands_df.dtypes
# Out:
# Unnamed: 0                                            int64
# NDC Description                                      object
# NDC                                                   int64
# NADAC_Per_Unit                                      float64
# Effective_Date                               datetime64[ns]
# Pricing_Unit                                         object
# Pharmacy_Type_Indicator                              object
# OTC                                                  object
# Explanation_Code                                     object
# Classification_for_Rate_Setting                      object
# Corresponding_Generic_Drug_NADAC_Per_Unit           float64
# Corresponding_Generic_Drug_Effective_Date            object
# As of Date                                           object
# dtype: object

# %%
top_20_drugs_df.dtypes

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.lineplot(x='Effective_Date', y='NADAC_Per_Unit', hue = 'NDC Description', data = top_20_drugs_df)
plt.title('Top 20 Generic Drug Prices per Unit over Time')
plt.savefig('./data/top_20_generic_timeseries.jpg');

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x='Effective_Date', y='NADAC_Per_Unit', hue = 'NDC Description', data = top_20_brands_df)
plt.title('Top 20 Brand Drug Prices per Unit over Time')
plt.savefig('./data/top_20_brand_timeseries.jpg');
#definitely want to look into zantac and also the drugs that are increasing in time

# %%
all_drugs = ps.read_csv
