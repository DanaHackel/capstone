# %%
import pandas as pd
import numpy as np

# %%
nadac = pd.read_csv('data/nadac_no_repeats.csv')

# %%
nadac.head()
nadac.drop(columns='Unnamed: 0', inplace=True)

# %%
nadac.head()
# Out:
#                  NDC Description          NDC  NADAC_Per_Unit Effective_Date  \
# 0    OLANZAPINE ODT 20 MG TABLET  65862065903         4.12341     12/23/2015
# 1  NYSTATIN 100,000 UNIT/GM POWD    904645602         0.60225     12/23/2015
# 2        OLANZAPINE 10 MG TABLET    904637661         0.22020     12/23/2015
# 3        CELECOXIB 50 MG CAPSULE  13811065860         0.51850     11/11/2015
# 4        LISINOPRIL 20 MG TABLET  51079098319         0.02633     12/17/2014
#
#   Pricing_Unit Pharmacy_Type_Indicator OTC Explanation_Code  \
# 0           EA                     C/I   N                1
# 1           GM                     C/I   N             1, 5
# 2           EA                     C/I   N                1
# 3           EA                     C/I   N                4
# 4           EA                     C/I   N                1
#
#   Classification_for_Rate_Setting  Corresponding_Generic_Drug_NADAC_Per_Unit  \
# ...

# %%
nadac.groupby(['NDC Description']).count()
# Out:
#                                 NDC  NADAC_Per_Unit  Effective_Date  \
# NDC Description
# 12-HR DECONGEST 120 MG CAPLET     4               4               4
# 12.5CPD-100GFN-30PSE LIQUID       1               1               1
# 12.5CPD-1DCPM-30PSE LIQUID        1               1               1
# 12HR NASAL DECONGEST ER 120 MG    2               2               2
# 24H NASAL ALLERGY 55 MCG SPRAY    1               1               1
# ...                             ...             ...             ...
# ZYTIGA 250 MG TABLET              1               1               1
# ZYVOX 100 MG/5 ML SUSPENSION      1               1               1
# ZYVOX 600 MG TABLET               4               4               4
# ZZZQUIL 25 MG LIQUICAP            4               4               4
# ZZZQUIL 50 MG/30 ML LIQUID        5               5               5
#
#                                 Pricing_Unit  Pharmacy_Type_Indicator  OTC  \
# NDC Description
# ...
